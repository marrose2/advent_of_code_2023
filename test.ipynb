# %%
import re
file1 = open('1_input', 'r')
Lines = file1.readlines()
 
# Strips the newline character
sum=0
pairs=[("zero","0")
    ,("one","1")
    ,("two","2")
    ,("three","3")
    ,("four","4")
    ,("five","5")
    ,("six","6")
    ,("seven","7")
    ,("eight","8")
    ,("nine","9")]
for line in Lines:
    pattern = r'[a-z]'
    str=line.strip()
    print(str)
    new_string=""
# Match all digits in the string and replace them with an empty string
    for i in range(len(str)):
        flag=True
        for string,num in pairs:
            if (str[i:i+len(string)]==string):
                new_string+=num
        if str[i] in ["1","2","3","4","5","6","7","8","9"]: new_string+=str[i]
    str=new_string[0]+new_string[-1]
    print(str)
    #print(new_string,str)
    sum+=int(str)
sum
# Out:
# mxmkjvgsdzfhseightonetwoeight7
# mxmk zero
# mxm one
# mxm two
# mxmkj three
# mxmk four
# mxmk five
# mxm six
# mxmkj seven
# mxmkj eight
# mxmk nine
# xmkj zero
# xmk one
# xmk two
# xmkjv three
# xmkj four
# xmkj five
# xmk six
# xmkjv seven
# xmkjv eight
# xmkj nine
# mkjv zero
# mkj one
# mkj two
# mkjvg three
# mkjv four
# mkjv five
# mkj six
# mkjvg seven
# mkjvg eight
# mkjv nine
# kjvg zero
# kjv one
# kjv two
# kjvgs three
# kjvg four
# kjvg five
# kjv six
# kjvgs seven
# kjvgs eight
# kjvg nine
# jvgs zero
# jvg one
# jvg two
# jvgsd three
# jvgs four
# jvgs five
# jvg six
# jvgsd seven
# jvgsd eight
# jvgs nine
# vgsd zero
# vgs one
# vgs two
# vgsdz three
# vgsd four
# vgsd five
# vgs six
# vgsdz seven
# vgsdz eight
# vgsd nine
# gsdz zero
# gsd one
# gsd two
# gsdzf three
# gsdz four
# gsdz five
# gsd six
# gsdzf seven
# gsdzf eight
# gsdz nine
# sdzf zero
# sdz one
# sdz two
# sdzfh three
# sdzf four
# sdzf five
# sdz six
# sdzfh seven
# sdzfh eight
# sdzf nine
# ...
